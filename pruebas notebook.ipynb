# %%
# The code was removed by DSX for sharing.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d4f61ed0ec75> in <module>()
#       8
#       9 data_df_1 = IdaDataFrame(idadb_8a27e28cdc1941ad964ef28e9182f703, 'DASH15016.GE2')
# ---> 10 data_df_1_df = data_df_1.as_dataframe()
#      11 #data_df_1.head()
#      12
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibmdbpy/utils.py in wrapper(*args, **kwds)
#      71         """Calculate elapsed time in seconds"""
#      72         start = time()
# ---> 73         result = function(*args, **kwds)
#      74         elapsed = time() - start
#      75         if os.environ['VERBOSE'] == 'True':
#
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ibmdbpy/internals.py in wrapper(self, *args, **kwds)
#      55                 self.internal_state.viewstack.append("(" + self.internal_state.get_state() + ")")
#      56             try:
# ...

# %%
data_df_1'EVENTO_CRITICO'].dtypes
#data_df_1_df = data_df_1.as_dataframe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f3f462bf134c> in <module>()
# ----> 1 str_df = data_df_1.select_dtypes([np.object])
#       2 #data_df_1_df = data_df_1.as_dataframe()
#
# AttributeError: 'IdaDataFrame' object has no attribute 'select_dtypes'

# %%
# The code was removed by DSX for sharing.
# Out:
#   EVENTO_CRITICO                          SERVIDOR        DETALLE_SERVIDOR  \
# 0       13326108       DR_IBM_FIREWALL_FTX190310ZK  Infraestructura_DR_IBM
# 1       13330639  SAN_TS1120 Tape Drive_DTC0200574                     SAN
# 2       13330583                    AS400 Nacional      Aplicaciones Apoyo
# 3       13297560  WASET01_WASPF01_ASBTS01_8.5.5.11      Application Server
# 4       13328019             Configuracion de LPAR    Aplicaciones Negocio
#
#          FECHA_ALERTA               ID VARIABLE_ALERTADA  \
# 0 2018-03-01 21:20:40         firewall          firewall
# 1 2018-03-02 14:57:35         cartucho          cartucho
# 2 2018-03-02 14:52:31            disco             disco
# 3 2018-02-26 06:56:39  hebras colgadas   hebras colgadas
# 4 2018-03-02 10:22:50             vios              vios
#
#                            DETALLE_VARIABLE_ALERTADA  CRITICO_MAYOR  \
# 0  Se requiere reinicio de firewall admin en call...              3
# ...
